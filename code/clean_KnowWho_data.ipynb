# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %%
src = "../data"
dst = "../data"

# %% [markdown]
# # KnowWho candidate list

# %% [markdown]
# ## Clean candidate list

# %%
# apparently from https://kw1.knowwho.com/candidate-data/candidate-lists/
fname = "candidates_exp09142022.csv"

profiles = pd.read_csv(Path(src, fname), parse_dates=["ELECTIONDATE"])
profiles = profiles.dropna(subset=["TWITTER2"])
dropcols = ["ELECTIONYEAR", "CYCLEFILINGDATE", "BUILDING", "ROOM",
            "STREET1", "STREET2", "CITY", "ZIPCODE", "PHONE", "FAX",
            "FECLINKNUM", "PROFILE", "INSTAGRAM", "LINKEDIN", "FACEBOOK",
            "WEBSITE", "YOUTUBE", "EMAIL", "TWITTER", "TWITTER2", "FACEBOOK2",
            'PREFIX', 'FIRSTNAME', 'MIDDLENAME', 'LASTNAME', 'SUFFIX', 
            'NICKNAME', "DISTRICTDESC", "STATE", "LASTUPDATED", "PERSONID"
           ]

profiles = profiles.drop(columns=dropcols)
races = ["US Representative", "US Senator", "US Delegate"]
profiles = profiles[profiles["RACE"].isin(races)]
profiles = profiles[profiles["PARTY"].isin(["R", "D"])]
profiles = profiles.dropna(subset=["ELECTIONDATE"])

# %%
profiles["ELECTIONCODE"].value_counts()
# Out:
# ELECTIONCODE
# P    1609
# S       7
# G       2
# R       1
# Name: count, dtype: int64

# %%
# this is a miscoding and the ELECTIONCODE should be "P" as
# Rebecca J. Viagran ran in the Democratic primaries in Texas on 2022-03-01
# similar to other Democratic candidates
# source: https://ballotpedia.org/Texas%27_35th_Congressional_District_election,_2022_(March_1_Democratic_primary)
profiles[profiles["ELECTIONCODE"] == "R"]
# Out:
#      INCUMBENT   STATUS ELECTIONCODE ELECTIONDATE STATEABBR LEVEL CHAMBER  \
# 3526       NaN  Running            R   2022-03-01        TX    FL      FH
#
#       DISTRICT               RACE ETHNICITY  GENDER PARTY      screen_name  \
# 3526      35.0  US Representative       NaN  Female     D  viagrancongress
#
#                     name
# 3526  Rebecca J. Viagran

# %%
profiles["ELECTIONCODE"] = profiles["ELECTIONCODE"].replace({"R":"P"})

# %%
# we exclude the special election that was held for Florida's 20th Congressional
# District on Jan 11, 2022.
# source: https://ballotpedia.org/Florida%27s_20th_Congressional_District_special_election,_2022
profiles[profiles["ELECTIONCODE"] == "G"]
# Out:
#     INCUMBENT                        STATUS ELECTIONCODE ELECTIONDATE  \
# 843       NaN  Defeated in Special Election            G   2022-01-11
# 856         Y          Won Special Election            G   2022-01-11
#
#     STATEABBR LEVEL CHAMBER  DISTRICT               RACE  \
# 843        FL    FL      FH      20.0  US Representative
# 856        FL    FL      FH      20.0  US Representative
#
#                   ETHNICITY  GENDER PARTY      screen_name  \
# 843         White/Caucasian    Male     R      votemariner
# 856  Black/African American  Female     D  sheila4congress
#
#                            name
# 843               Jason Mariner
# 856  Sheila Cherfilus-McCormick

# %%
# we exclude the special election that was held for California's 22th 
# Congressional District on Apr 5, 2022.
# source: https://ballotpedia.org/California%27s_22nd_Congressional_District_special_election,_2022

# we exclude the special election that was held for Florida's 20th Congressional 
# District on Nov 2, 2022.
# source: https://ballotpedia.org/Natalia_Allen
profiles[profiles["ELECTIONCODE"] == "S"]
# Out:
#     INCUMBENT              STATUS ELECTIONCODE ELECTIONDATE STATEABBR LEVEL  \
# 381       NaN  Withdrew From Race            S   2022-04-05        CA    FL
# 384       NaN             Running            S   2022-04-05        CA    FL
# 385       NaN             Running            S   2022-04-05        CA    FL
# 386       NaN  Withdrew From Race            S   2022-04-05        CA    FL
# 389       NaN             Running            S   2022-04-05        CA    FL
# 392       NaN  Withdrew From Race            S   2022-04-05        CA    FL
# 847       NaN   Failed To Qualify            S   2022-11-02        FL    FL
#
#     CHAMBER  DISTRICT               RACE               ETHNICITY  GENDER  \
# 381      FH      22.0  US Representative                     NaN    Male
# 384      FH      22.0  US Representative  Black/African American    Male
# 385      FH      22.0  US Representative         Hispanic/Latino    Male
# 386      FH      22.0  US Representative                     NaN    Male
# 389      FH      22.0  US Representative  Asian/Pacific American  Female
# 392      FH      22.0  US Representative         Hispanic/Latino    Male
# 847      FH      20.0  US Representative                     NaN  Female
#
#     PARTY     screen_name              name
# 381     R  nathanmagsigca     Nathan Magsig
# 384     D   lourinhubbard    Lourin Hubbard
# 385     D       ericg1247       Eric Garcia
# 386     D     philarballo      Phil Arballo
# 389     R   elizabethheng    Elizabeth Heng
# 392     R     johnestrada   John A. Estrada
# 847     D  nataliaallenfl  Natalia I. Allen

# %%
profiles = profiles[profiles["ELECTIONCODE"] == "P"]

# %%
# "primaries" on 2023-11-08 are all from Louisiana. Louisiana elections use the 
# Louisiana majority-vote system. All candidates compete in the same primary, 
# and a candidate can win the election outright by receiving more than 50% of 
# the vote. If no candidate does, the top two vote recipients from the primary 
# advance to the general election, regardless of their partisan affiliation.
# source: https://ballotpedia.org/Louisiana's_3rd_Congressional_District_election,_2022
profiles[profiles["ELECTIONDATE"] == pd.to_datetime("2022-11-08")]
# Out:
#      INCUMBENT              STATUS ELECTIONCODE ELECTIONDATE STATEABBR LEVEL  \
# 2200         Y             Running            P   2022-11-08        LA    FL
# 2202         Y             Running            P   2022-11-08        LA    FL
# 2204       NaN  Withdrew From Race            P   2022-11-08        LA    FL
# 2205         Y             Running            P   2022-11-08        LA    FL
# 2207         Y             Running            P   2022-11-08        LA    FL
# 2208         Y             Running            P   2022-11-08        LA    FL
# 2209         Y             Running            P   2022-11-08        LA    FL
# 2215       NaN             Running            P   2022-11-08        LA    FL
# 2216         Y             Running            P   2022-11-08        LA    FL
#
#      CHAMBER  DISTRICT               RACE               ETHNICITY  GENDER  \
# 2200      FH       1.0  US Representative         White/Caucasian    Male
# 2202      FH       2.0  US Representative  Black/African American    Male
# 2204      FH       3.0  US Representative         White/Caucasian    Male
# 2205      FH       3.0  US Representative         White/Caucasian    Male
# 2207      FH       4.0  US Representative         White/Caucasian    Male
# 2208      FH       5.0  US Representative         White/Caucasian  Female
# 2209      FH       6.0  US Representative         White/Caucasian    Male
# 2215      FS       NaN         US Senator  Black/African American    Male
# 2216      FS       NaN         US Senator         White/Caucasian    Male
#
#      PARTY      screen_name            name
# 2200     R  stevescalisegop   Steve Scalise
# 2202     D   troyc4congress     Troy Carter
# 2204     D     grangerforla  Dustin Granger
# 2205     R  captclayhiggins    Clay Higgins
# 2207     R      mikejohnson    Mike Johnson
# 2208     R         jbletlow    Julia Letlow
# 2209     R     garretgraves   Garret Graves
# 2215     D   garychambersjr   Gary Chambers
# 2216     R    johnkennedyla    John Kennedy

# %%
profiles["ELECTIONCODE"].value_counts()
# Out:
# ELECTIONCODE
# P    1610
# Name: count, dtype: int64

# %%
profiles = profiles.drop_duplicates(subset=["name", "PARTY", "STATEABBR", "screen_name"])
len(profiles)
# Out:
# 1596

# %%
len(profiles[profiles["INCUMBENT"] == "Y"])
# Out:
# 401

# %%
len(profiles["screen_name"].dropna())
# Out:
# 1596

# %%
# there seem to be a few errors in the KnowHow data, which we manually correct
profile_counts = profiles["screen_name"].value_counts().reset_index()
profile_counts = profile_counts[profile_counts["count"] > 1]
profiles[profiles["screen_name"].isin(profile_counts["screen_name"])]
# Out:
#      INCUMBENT              STATUS ELECTIONCODE ELECTIONDATE STATEABBR LEVEL  \
# 186        NaN             Running            P   2022-05-24        AL    FL
# 262        NaN             Running            P   2022-08-02        AZ    FL
# 293        NaN             Running            P   2022-05-24        AR    FL
# 294        NaN  Withdrew From Race            P   2022-05-24        AR    FL
# 311        NaN             Running            P   2022-06-07        CA    FL
# 398        NaN             Running            P   2022-06-07        CA    FL
# 1887       NaN             Running            P   2022-08-02        KS    FL
# 2634       NaN             Running            P   2022-06-07        NJ    FL
# 2642         Y  Withdrew From Race            P   2022-06-07        NJ    FL
# 2657       NaN  Withdrew From Race            P   2022-06-07        NM    FL
# 2716       NaN             Running            P   2022-06-28        NY    FL
# 3051       NaN             Running            P   2022-06-28        OK    FL
# 3102       NaN             Running            P   2022-05-17        PA    FL
# 3192       NaN  Withdrew From Race            P   2022-05-17        PA    FL
#
#      CHAMBER  DISTRICT               RACE               ETHNICITY  GENDER  \
# 186       FS       NaN         US Senator  Black/African American    Male
# 262       FH       7.0  US Representative         White/Caucasian    Male
# 293       FH       2.0  US Representative  Black/African American  Female
# 294       FH       2.0  US Representative                     NaN    Male
# 311       FH       1.0  US Representative                     NaN    Male
# 398       FH      23.0  US Representative         White/Caucasian    Male
# 1887      FS       NaN         US Senator         White/Caucasian  Female
# 2634      FH       7.0  US Representative                     NaN    Male
# 2642      FH       8.0  US Representative         Hispanic/Latino    Male
# 2657      FH       2.0  US Representative         White/Caucasian    Male
# 2716      FH       2.0  US Representative         White/Caucasian    Male
# 3051      FS       NaN         US Senator         White/Caucasian  Female
# 3102      FH       1.0  US Representative                     NaN    Male
# 3192      FS       NaN         US Senator  Black/African American    Male
#
#      PARTY     screen_name                name
# 186      D    brandaundean    Brandaun L. Dean
# 262      R    realjeffzink     Jeffrey N. Zink
# 293      D   ncartwrightar  Quintessa Hathaway
# 294      D   ncartwrightar  Nicolas Cartwright
# 311      D    realjeffzink     David Leon Zink
# 398      D    brunoamato_1         Bruno Amato
# 1887     R       farrforus        Joan E. Farr
# 2634     R     rikmehta_nj         Rikin Mehta
# 2642     D     rikmehta_nj         Albio Sires
# 2657     R  mike4congress2  Michael Rakebrandt
# 2716     R  mike4congress2  Michael Rakebrandt
# 3051     R       farrforus        Joan E. Farr
# 3102     D    brunoamato_1       Eric M. Bruno
# 3192     D    brandaundean    Brandaun L. Dean

# %%
# Brandaun L. Dean ran in AL, not PA. Source: https://ballotpedia.org/Brandaun_Dean
# Michael Rakebrandt withdrew from race in NM
profiles = profiles.drop(index=[3192, 2657])

# Twitter profile entry for David Leon Zink is wrong and belongs to Jeffrey N. Zink
profiles.loc[311, "screen_name"] = np.nan
# Twitter profile entry for Quintessa Hathaway is wrong and belongs to Nicolas Cartwright
profiles.loc[293, "screen_name"] = np.nan
# Twitter profile entry for Eric M. Bruno is wrong and belongs to Bruno Amato
profiles.loc[3102, "screen_name"] = np.nan
# Twitter profile entry for Albio Sires is wrong and belongs to Rikin Mehta
profiles.loc[2642, "screen_name"] = np.nan

# Joan E. Farr ran for senate in both OK and KS. 
# Source: https://ballotpedia.org/Joan_Farr

# %%
# sanity check: only Joan Farr should remain
profile_counts = profiles["screen_name"].value_counts().reset_index()
profile_counts = profile_counts[profile_counts["count"] > 1]
profiles[profiles["screen_name"].isin(profile_counts["screen_name"])]
# Out:
#      INCUMBENT   STATUS ELECTIONCODE ELECTIONDATE STATEABBR LEVEL CHAMBER  \
# 1887       NaN  Running            P   2022-08-02        KS    FL      FS
# 3051       NaN  Running            P   2022-06-28        OK    FL      FS
#
#       DISTRICT        RACE        ETHNICITY  GENDER PARTY screen_name  \
# 1887       NaN  US Senator  White/Caucasian  Female     R   farrforus
# 3051       NaN  US Senator  White/Caucasian  Female     R   farrforus
#
#               name
# 1887  Joan E. Farr
# 3051  Joan E. Farr

# %%
fname = "KnowWho_profiles_clean.csv"
profiles.to_csv(Path(dst, fname), index=False)
